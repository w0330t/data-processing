# %%
import pandas as pd
import numpy as np
import common

from pyecharts.charts import Kline
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
df = common.read_kline_data('data/ETH_USDT_USDT-1h-futures.json')

# %%
df = df.iloc[-100:]

# %%
data = []
for _, row in df.iterrows():
    data.append([
        row["open"], 
        row["close"], 
        row["low"], 
        row["high"], 
    ])

# %%
kline = (
    Kline(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
    .add_xaxis(df["datetime"].tolist())
    .add_yaxis("K线图", data)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(is_scale=True),
        datazoom_opts=[opts.DataZoomOpts()],
        title_opts=opts.TitleOpts(title="K线图")
    )
)

# %%
kline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/v5/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="b98f3e12493942d4a036e561bd4cf552" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_b98f3e12493942d4a036e561bd4cf552 = echarts.init(
#                     document.getElementById('b98f3e12493942d4a036e561bd4cf552'), 'chalk', {renderer: 'canvas'});
#                 var option_b98f3e12493942d4a036e561bd4cf552 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "K\u7ebf\u56fe",
#             "colorBy": "series",
#             "data": [
#                 [
#                     1747.22,
#                     1744.76,
#                     1741.01,
#                     1747.86
#                 ],
#                 [
#                     1744.77,
#                     1746.21,
#                     1741.09,
#                     1746.27
#                 ],
#                 [
#                     1746.21,
#                     1738.67,
#                     1735.1,
#                     1746.25
#                 ],
#                 [
#                     1738.67,
#                     1737.3,
#                     1727.01,
#                     1743.48
#                 ],
#                 [
#                     1737.29,
#                     1730.8,
#                     1729.14,
#                     1737.32
#                 ],
#                 [
#                     1730.81,
#                     1735.39,
#                     1725.72,
#                     1738.49
#                 ],
#                 [
#                     1735.4,
#                     1735.38,
#                     1719.29,
#                     1746.89
#                 ],
#                 [
#                     1735.37,
#                     1736.04,
#                     1729.06,
#                     1737.71
#                 ],
#                 [
#                     1736.05,
#                     1732.18,
#                     1726.69,
#                     1736.6
#                 ],
#                 [
#                     1732.17,
#                     1738.61,
#                     1729.51,
#                     1738.85
#                 ],
#                 [
#                     1738.62,
#                     1742.6,
#                     1737.29,
#                     1743.6
#                 ],
#                 [
#                     1742.61,
#                     1742.36,
#                     1740.0,
#                     1745.84
#                 ],
#                 [
#                     1742.36,
#                     1741.61,
#                     1739.65,
#                     1743.75
#                 ],
#                 [
#                     1741.6,
#                     1732.07,
#                     1727.68,
#                     1749.91
#                 ],
#                 [
#                     1732.06,
#                     1739.61,
#                     1727.4,
#                     1747.68
#                 ],
#                 [
#                     1739.6,
#                     1752.84,
#                     1736.51,
#                     1755.99
#                 ],
#                 [
#                     1752.84,
#                     1746.55,
#                     1744.45,
#                     1753.81
#                 ],
#                 [
#                     1746.55,
#                     1747.0,
#                     1740.0,
#                     1747.86
#                 ],
#                 [
#                     1747.0,
#                     1748.58,
#                     1746.17,
#                     1751.9
#                 ],
#                 [
#                     1748.58,
#                     1748.09,
#                     1746.32,
#                     1752.58
#                 ],
#                 [
#                     1748.09,
#                     1747.26,
#                     1746.96,
#                     1751.75
#                 ],
#                 [
#                     1747.27,
#                     1752.42,
#                     1745.94,
#                     1758.8
#                 ],
#                 [
#                     1752.43,
#                     1748.85,
#                     1746.1,
#                     1754.73
#                 ],
#                 [
#                     1748.85,
#                     1750.21,
#                     1746.49,
#                     1751.12
#                 ],
#                 [
#                     1750.21,
#                     1753.06,
#                     1745.22,
#                     1754.95
#                 ],
#                 [
#                     1753.06,
#                     1741.37,
#                     1726.0,
#                     1766.53
#                 ],
#                 [
#                     1741.38,
#                     1737.72,
#                     1735.41,
#                     1745.89
#                 ],
#                 [
#                     1737.72,
#                     1739.4,
#                     1730.2,
#                     1740.52
#                 ],
#                 [
#                     1739.39,
#                     1729.58,
#                     1722.53,
#                     1739.4
#                 ],
#                 [
#                     1729.58,
#                     1737.52,
#                     1728.56,
#                     1738.8
#                 ],
#                 [
#                     1737.51,
#                     1736.2,
#                     1733.39,
#                     1739.98
#                 ],
#                 [
#                     1736.21,
#                     1740.16,
#                     1734.19,
#                     1750.47
#                 ],
#                 [
#                     1740.15,
#                     1739.72,
#                     1738.12,
#                     1743.92
#                 ],
#                 [
#                     1739.73,
#                     1737.75,
#                     1735.7,
#                     1743.88
#                 ],
#                 [
#                     1737.74,
#                     1738.24,
#                     1735.38,
#                     1740.1
#                 ],
#                 [
#                     1738.24,
#                     1733.98,
#                     1732.38,
#                     1740.09
#                 ],
#                 [
#                     1733.98,
#                     1739.24,
#                     1733.97,
#                     1739.73
#                 ],
#                 [
#                     1739.24,
#                     1743.91,
#                     1737.63,
#                     1745.7
#                 ],
#                 [
#                     1743.91,
#                     1746.66,
#                     1740.9,
#                     1746.9
#                 ],
#                 [
#                     1746.67,
#                     1746.05,
#                     1743.51,
#                     1748.0
#                 ],
#                 [
#                     1746.05,
#                     1745.55,
#                     1743.13,
#                     1746.82
#                 ],
#                 [
#                     1745.55,
#                     1741.33,
#                     1740.5,
#                     1746.54
#                 ],
#                 [
#                     1741.33,
#                     1737.51,
#                     1735.8,
#                     1742.0
#                 ],
#                 [
#                     1737.51,
#                     1740.33,
#                     1736.53,
#                     1740.75
#                 ],
#                 [
#                     1740.32,
#                     1740.4,
#                     1737.86,
#                     1741.67
#                 ],
#                 [
#                     1740.4,
#                     1743.4,
#                     1739.96,
